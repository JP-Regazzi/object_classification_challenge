# %% [markdown]
# ## Import modules

# %%
import os
import torch
import pandas as pd
from PIL import Image
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision.io import read_image
from random import random, randrange
from torchvision import transforms,models
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import clip
from copy import deepcopy

# %% [markdown]
# ## Import clip model

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model, preprocess = clip.load("ViT-B/32",device="cpu")

# %% [markdown]
# ## Creating images lists

# %%
CLEAN_IMAGES_CSV_PATH = os.path.join("data","DAM")
reference_images = [os.path.join(CLEAN_IMAGES_CSV_PATH, img)for img in os.listdir(CLEAN_IMAGES_CSV_PATH)]

TEST_IMAGES_PATH = os.path.join("data","test_image_headmind")
img_list = [os.path.join(TEST_IMAGES_PATH,i) for i in os.listdir(TEST_IMAGES_PATH)]

# %% [markdown]
# ## Creating Answers Directory

# %%
csv_all = pd.read_csv("results17-32.csv",header=None, sep=", ")
csv_arthur = pd.read_csv("answer65-80.csv", header=None, sep=", ")
csv_all = pd.concat([pd.read_csv("answers1-16.csv", header=None, sep= ", "),csv_all, pd.read_csv("results33-48.csv", header=None, sep=", "), pd.read_csv("results49-64.csv", header=None, sep=", "), csv_arthur])
csv_all.head()
csv_all.columns = ['0','1']
# Out:
# C:\Users\arthu\AppData\Local\Temp\ipykernel_1264\4145771647.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   csv_all = pd.read_csv("results17-32.csv",header=None, sep=", ")
# C:\Users\arthu\AppData\Local\Temp\ipykernel_1264\4145771647.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   csv_arthur = pd.read_csv("answer65-80.csv", header=None, sep=", ")
# C:\Users\arthu\AppData\Local\Temp\ipykernel_1264\4145771647.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   csv_all = pd.concat([pd.read_csv("answers1-16.csv", header=None, sep= ", "),csv_all, pd.read_csv("results33-48.csv", header=None, sep=", "), pd.read_csv("results49-64.csv", header=None, sep=", "), csv_arthur])
# C:\Users\arthu\AppData\Local\Temp\ipykernel_1264\4145771647.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   csv_all = pd.concat([pd.read_csv("answers1-16.csv", header=None, sep= ", "),csv_all, pd.read_csv("results33-48.csv", header=None, sep=", "), pd.read_csv("results49-64.csv", header=None, sep=", "), csv_arthur])
# C:\Users\arthu\AppData\Local\Temp\ipykernel_1264\4145771647.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   csv_all = pd.concat([pd.read_csv("answers1-16.csv", header=None, sep= ", "),csv_all, pd.read_csv("results33-48.csv", header=None, sep=", "), pd.read_csv("results49-64.csv", header=None, sep=", "), csv_arthur])

# %%
print(csv_all)
# Out:
#                   0                               1
# 0     M0538OCALM35R  image-20210928-102713-12d2869d
# 1     M0505SLOIM989  image-20210928-102718-2474636a
# 2     M0565ONGEM50P  image-20210928-102721-8eaea48f
# 3     M9203UWDIM59E  image-20210928-102725-7e28b44c
# 4     M9204UMOAM918  image-20210928-102725-7e28b44c
# ..              ...                             ...
# 12  SOSTELAIR1SZJ86         MicrosoftTeams-image_46
# 13  SOSTELAIR1807YB         MicrosoftTeams-image_48
# 14    DSGTS6UXR10A0         MicrosoftTeams-image_50
# 15    S5652CBAAM41G         MicrosoftTeams-image_53
# 16    S5652CCEHM900         MicrosoftTeams-image_54
#
# [96 rows x 2 columns]

# %%
answers = {}
for _, row in csv_all.iterrows():
    if row['1'] in answers.keys():
        answers[row['1']].append(row['0'])
    else:
        answers[row['1']] = [row['0']]

# %% [markdown]
# ## Creating embeddings for the referrence images

# %%
reference_features = []
for img in tqdm(reference_images):
    image = preprocess(Image.open(img)).unsqueeze(0)
    with torch.no_grad():
        reference_features.append(model.encode_image(image).flatten())
# Out:
# 100%|██████████| 2766/2766 [05:05<00:00,  9.06it/s]

# %% [markdown]
# ## Creating embeddings for the client images

# %%
client_features = []
for img in tqdm(img_list):
    image = preprocess(Image.open(img)).unsqueeze(0)
    with torch.no_grad():
        client_features.append(model.encode_image(image).flatten())
# Out:
# 100%|██████████| 80/80 [00:19<00:00,  4.13it/s]

# %% [markdown]
# ## Retrieving the top 5 most similar items

# %%
client_embedding_tensor = torch.stack(client_features).squeeze(1)
embedding_tensor = torch.stack(reference_features).squeeze(1)

client_embedding_tensor_normalized = client_embedding_tensor / client_embedding_tensor.norm(dim=1, keepdim=True)
embedding_tensor_normalized = embedding_tensor / embedding_tensor.norm(dim=1, keepdim=True)

cosine_similarities = torch.mm(client_embedding_tensor_normalized, embedding_tensor_normalized.t())

closest_indices = torch.argsort(cosine_similarities, dim=1,descending=True)[:,:10]
closest_indices
# Out:
# tensor([[2017, 1772, 2115, 2074, 2163, 2154, 2109, 2110, 1681, 1658],
#         [1896, 2163, 1735, 1895, 1873, 1654, 2205, 1743, 2089, 2464],
#         [2163, 2085, 2430, 2763, 1638, 1978, 1613, 2190, 1800, 2646],
#         [2280, 2263, 2243, 2269, 2430, 2676, 2270, 2583, 2582, 2255],
#         [2676, 2243, 2263, 2247, 2245, 2421, 2680, 2660, 2583, 2335],
#         [1492, 1426, 1435, 1500, 1510, 1467, 1472, 1433, 1327, 1431],
#         [1864, 2536, 2267, 2236, 2163, 2190, 1982, 2464, 1571, 2280],
#         [1735, 1654, 2464, 2628, 1659, 2086, 1641, 2040, 1645, 2523],
#         [2628, 2644, 1583, 1735, 2646, 2280, 1353, 2684, 2685, 2625],
#         [1934, 1828, 1827, 1926, 2625, 2644, 2289, 2290, 1549, 1958],
#         [ 659,  660, 1076,  854, 1169, 2678, 1558, 1571, 1548, 1581],
#         [ 259, 1302, 2277, 1571, 1546, 2280, 2628, 2678, 2278, 1195],
#         [1036, 1034, 1024, 1355, 1035,  259, 1354,  665, 2439, 1022],
#         [1354, 1022, 1024, 1036, 1023, 2664, 1502, 1027, 1355, 2489],
#         [1717, 2076, 1735, 2523, 1770, 2426, 2267, 1790, 2296, 1711],
#         [1654, 2271, 2279, 2267, 2286, 2282, 2280, 2048, 2082, 1546],
#         [1220, 1446, 1238, 1412, 1302, 1445, 1217, 1218, 1457, 1453],
#         [1415, 1416, 1235, 1412, 1237, 1382,  140, 1183,  259, 1453],
#         [1269, 1397, 1403, 1288, 1456, 1268, 1276, 1284, 1267, 1394],
#         [1186, 1266, 1291, 1276, 1297, 1277, 1420, 1288, 1190, 1439],
#         [1266, 1291, 1277, 1263, 1297, 1262, 1265, 1276, 1288, 1245],
#         [1266, 1420, 1277, 1291, 1293, 1297, 1250, 1195, 1276, 1186],
#         [1266, 1276, 1262, 1291, 1245, 1263, 1277, 1297, 1244, 1265],
#         [1453, 1220, 1446, 1455, 1266, 1239, 1233, 1302, 1217, 1213],
#         [ 659,  660, 1076, 1067, 2740, 2381,  662,  661, 1073, 1069],
#         [1076,  657, 2740, 1067, 1050,  665, 1074,  658, 2381,  659],
#         [2740, 1076, 1067,  660,  657, 1066,  658, 1074, 2381, 1065],
#         [ 905, 1076,  903,  657, 1074, 2764, 1169,  664, 1067, 1173],
#         [1076,  657,  665, 2740, 1065, 1067,  659, 1074, 2381,  906],
#         [1076,  665,  663,  659, 1174, 1071, 1070,  660,  657, 1079],
#         [1034, 1036, 1035, 1076,  665, 1033,  259, 2277,  845, 1078],
#         [1076,  657, 1074,  665, 1067,  904,  659, 2740,  906,  658],
#         [1066, 1074, 1076, 1075, 1067, 1173, 2740, 1078, 2381, 1077],
#         [ 664, 1076,  903,  658,  663, 2737, 2764, 1173,  660, 2740],
#         [ 660,  659, 2740, 2745, 1169, 2381, 2735, 1171, 1076,  658],
#         [1982, 2562, 1525, 2566, 2665, 2464, 2582, 2470, 1864, 1981],
#         [2250, 2280, 2059, 2236, 1599, 1670, 1638, 1629, 2255, 2234],
#         [2237, 2474, 2236, 2562, 1654, 2267, 2470, 2065, 2491, 2475],
#         [2280, 2271, 2267, 2266, 2285, 2668, 1546, 2582, 2583, 2270],
#         [ 262, 1127, 1034,  105, 2011, 2009,  184,  239, 2439,   58],
#         [1571, 1567, 1995, 1548, 1996, 2280, 2010, 1570, 1540, 1587],
#         [1933, 1914, 1973, 1962, 1970, 1928, 1832, 1971, 1936, 1969],
#         [1827, 1828, 1934, 2651, 1928, 1914, 1973, 1970, 1933, 2289],
#         [1580, 1571, 2582, 1772, 2217, 2678, 1976, 2263, 2243, 2261],
#         [2076, 1817, 1875, 2163, 2168, 1743, 1670, 1818, 2205, 2187],
#         [1778, 1631, 2468, 1752, 2441, 2492, 1978, 1821, 2313, 2478],
#         [2464, 2311, 2163, 2492, 1799, 1817, 2187, 2460, 1735, 2076],
#         [ 961,  954,  919, 2399,  994,  982,  971,  922,  936,  986],
#         [2588, 1034, 1036, 2489, 1035, 1354, 1022,  845, 1052, 2399],
#         [2399, 1034, 2072,  961, 2086, 2023, 1670, 2094, 1035, 1677],
#         [ 233,  259,  232,  241,  650,  836,   93,  703,  231, 2277],
#         [1633, 1767, 1631, 1821, 1762, 1777, 1820, 1788, 1778, 1790],
#         [1817, 2076, 2187, 1799, 1768,  910, 2168, 1818, 1790, 1875],
#         [1195, 1302, 1266, 1183,  602, 1412,  259, 1235,  274,  651],
#         [1274, 1266, 1262, 1264, 1282, 1195, 1269, 1272, 1397, 1290],
#         [1285, 1385, 1397, 1403, 1195, 1456, 1254, 1287, 1273, 1269],
#         [1368, 1051, 1302, 1379, 1127, 2280, 1386, 2667, 1195, 1380],
#         [1368, 1383, 1369, 1386, 1051, 1380, 1345, 1390, 1379, 1378],
#         [1190, 1297, 1420, 1419, 1345, 1327, 1467, 1423, 1424, 1362],
#         [1492, 1426, 1435, 1312, 1331, 1469, 1327, 1467, 1500, 1217],
#         [1313, 1466, 1489, 1484, 1304, 1302, 1490, 1324, 1436, 1435],
#         [1450, 1231, 1453, 1237, 1238, 1451, 1455, 1456, 1457,  154],
#         [1439, 1206, 1200, 1313, 1438, 1204, 1205, 1302, 1436, 1303],
#         [1435, 1427, 1434, 1177, 1432, 1198, 1510, 1309, 1390, 1175],
#         [1238, 1455, 1220, 1446, 1453, 1457, 1454, 1229, 1232, 1451],
#         [1451, 1454, 1232, 1455, 1449, 1220, 1446, 1453, 1229, 1219],
#         [1454, 1232, 1451, 1220, 1446, 1449, 1455, 1217, 1222, 1453],
#         [1213, 1224, 1455, 1236, 1219, 1227, 1226, 1239, 1229, 1451],
#         [1276, 1297, 1245, 1291, 1288, 1223, 1244, 1183, 1235, 1262],
#         [1276, 1288, 1245, 1291, 1277, 1263, 1223, 1265, 1244, 1297],
#         [1291, 1297, 1223, 1266, 1276, 1288, 1262, 1245, 1277, 1397],
#         [1284, 1397, 1288, 1276, 1396, 1223, 1403, 1291, 1268, 1269],
#         [1076,  665, 1050,  659,  658,  662,  657, 1067, 2740,  664],
#         [1076, 1074,  657, 1067, 2740, 1069, 2381,  659,  658,  906],
#         [1076, 2740,  658, 2381, 1067,  657,  659,  665,  656, 1050],
#         [1076,  657,  903,  665,  904, 1070,  663,  664, 2740, 1065],
#         [1076, 2740,  657,  658, 2738, 2741, 1065, 1075,  665, 1067],
#         [1076,  657,  665,  904, 2740,  659, 1067, 2381, 1074, 1050],
#         [2675, 2676, 2671, 2680, 2660, 2683, 2243, 2263, 2421, 2686],
#         [2675, 2267,  844, 2683, 1982, 2676, 2680, 2426, 2583, 2286]])

# %%
closest_indices[0]
# Out:
# tensor([1660, 1663, 1666, 1780, 1756])

# %%
guesses = {}

for i, img in enumerate(img_list):
    file_name = img.split("\\")[-1]
    img_id = file_name.split(".")[0]
    guesses[img_id] = [reference_images[ind] for ind in closest_indices[i].tolist()]

# %%
guesses
# Out:
# {'image-20210928-102713-12d2869d': ['data\\DAM\\M500SJAAUXM334.jpeg',
#   'data\\DAM\\M0538OCALM35R.jpeg',
#   'data\\DAM\\M531SJAUGXM334.jpeg',
#   'data\\DAM\\M505SOAAUXM43R.jpeg',
#   'data\\DAM\\M565SOAAUXM830.jpeg'],
#  'image-20210928-102718-2474636a': ['data\\DAM\\M0566PAWAXM90B.jpeg',
#   'data\\DAM\\M565SOAAUXM830.jpeg',
#   'data\\DAM\\M0531NWDDM900.jpeg',
#   'data\\DAM\\M0566PAWAXM85B.jpeg',
#   'data\\DAM\\M0566JAWAXM85B.jpeg'],
#  'image-20210928-102721-8eaea48f': ['data\\DAM\\M565SOAAUXM830.jpeg',
#   'data\\DAM\\M505SOLAAXM79B.jpeg',
#   'data\\DAM\\S0110ONMJM43F.jpeg',
#   'data\\DAM\\VRB44560N0.jpeg',
#   'data\\DAM\\M0505JAWAXM41G.jpeg'],
#  'image-20210928-102725-7e28b44c': ['data\\DAM\\M9204ULERXM423.jpeg',
#   'data\\DAM\\M9203UMOSM46E.jpeg',
#   'data\\DAM\\M9203CMOSM46E.jpeg',
#   'data\\DAM\\M9203UWDIM59E.jpeg',
#   'data\\DAM\\S0110ONMJM43F.jpeg'],
#  'image-20210928-102729-f53d9faf': ['data\\DAM\\S5652CWGSM919.jpeg',
#   'data\\DAM\\M9203CMOSM46E.jpeg',
#   'data\\DAM\\M9203UMOSM46E.jpeg',
#   'data\\DAM\\M9203JKARM49P.jpeg',
#   'data\\DAM\\M9203IBAVM50P.jpeg'],
#  'image-20210928-102732-8502aded': ['data\\DAM\\KDP916LNYS27G.jpeg',
#   'data\\DAM\\KDB704LNYS26U.jpeg',
#   'data\\DAM\\KDB805VNIS900.jpeg',
#   'data\\DAM\\KDQ229VEAS900.jpeg',
#   'data\\DAM\\KDV042VNIS900.jpeg'],
#  'image-20210928-102747-05631ad4': ['data\\DAM\\M0565STBHM042.jpeg',
#   'data\\DAM\\S0949HAQRJM042.jpeg',
#   'data\\DAM\\M9203UTFQM928.jpeg',
#   'data\\DAM\\M8641ULJGM889.jpeg',
#   'data\\DAM\\M565SOAAUXM830.jpeg'],
#  'image-20210928-102758-fd41d453': ['data\\DAM\\M0531NWDDM900.jpeg',
#   'data\\DAM\\M0505OAWAXM85B.jpeg',
#   'data\\DAM\\S0204OAHGXM830.jpeg',
#   'data\\DAM\\S5420VRIWM928.jpeg',
#   'data\\DAM\\M0505OAZEXM900.jpeg'],
#  'image-20210928-102802-39d3c54f': ['data\\DAM\\S5420VRIWM928.jpeg',
#   'data\\DAM\\S5494SLNCN0N1.jpeg',
#   'data\\DAM\\M0447SSRTM49E.jpeg',
#   'data\\DAM\\M0531NWDDM900.jpeg',
#   'data\\DAM\\S5494VNTJM912.jpeg'],
#  'image-20210928-102806-79d7094b': ['data\\DAM\\M1286ZRHMM918.jpeg',
#   'data\\DAM\\M0565ORHMM918.jpeg',
#   'data\\DAM\\M0565ORHMM842.jpeg',
#   'data\\DAM\\M1286ZGSBM49P.jpeg',
#   'data\\DAM\\S5414CTZQM928.jpeg'],
#  'image-20210928-102940-20cd277d': ['data\\DAM\\30MNTGN8072K.jpeg',
#   'data\\DAM\\30MNTGNSZJ1I.jpeg',
#   'data\\DAM\\DSGTS1UXR10A0.jpeg',
#   'data\\DAM\\B0262WWPOM939.jpeg',
#   'data\\DAM\\EVDRR1UQRD0F1.jpeg'],
#  'image-20210928-103146-c8d2fedb': ['data\\DAM\\122J02X3376X0891.jpeg',
#   'data\\DAM\\KCP261LSRS12U.jpeg',
#   'data\\DAM\\M9204UCHFXM030.jpeg',
#   'data\\DAM\\M0447CANGM22L.jpeg',
#   'data\\DAM\\M0446CSAZM49E.jpeg'],
#  'image-20210928-103157-a46cc321': ['data\\DAM\\CDBM150070000.jpeg',
#   'data\\DAM\\CDBM150050000.jpeg',
#   'data\\DAM\\CDBC080060000.jpeg',
#   'data\\DAM\\KCQ209TJES34G.jpeg',
#   'data\\DAM\\CDBM150060000.jpeg'],
#  'image-20210928-103200-ce51703f': ['data\\DAM\\KCQ209TDES42H.jpeg',
#   'data\\DAM\\CDBC041140000.jpeg',
#   'data\\DAM\\CDBC080060000.jpeg',
#   'data\\DAM\\CDBM150070000.jpeg',
#   'data\\DAM\\CDBC080030000.jpeg'],
#  'image-20210928-103217-38e9a47d': ['data\\DAM\\M0505SNEAM900.jpeg',
#   'data\\DAM\\M505SOAHGM900.jpeg',
#   'data\\DAM\\M0531NWDDM900.jpeg',
#   'data\\DAM\\S0856OWCBM900.jpeg',
#   'data\\DAM\\M0538ILOIM94B.jpeg'],
#  'image-20210928-103240-bd2d326b': ['data\\DAM\\M0505OAWAXM85B.jpeg',
#   'data\\DAM\\M9203UYECM90B.jpeg',
#   'data\\DAM\\M9204UCYMXM85B.jpeg',
#   'data\\DAM\\M9203UTFQM928.jpeg',
#   'data\\DAM\\M9206UAYCM61E.jpeg'],
#  'image-20210928-103700-a406b29c': ['data\\DAM\\KCI592VSOS900.jpeg',
#   'data\\DAM\\KDI592VSOS900.jpeg',
#   'data\\DAM\\KCI781VEAS17X.jpeg',
#   'data\\DAM\\KCQ810XLCS03W.jpeg',
#   'data\\DAM\\KCP261LSRS12U.jpeg'],
#  'image-20210928-103707-a441ed0e': ['data\\DAM\\KCQ858SBXS70K.jpeg',
#   'data\\DAM\\KCQ858SBXS89K.jpeg',
#   'data\\DAM\\KCI762NSRS03W.jpeg',
#   'data\\DAM\\KCQ810XLCS03W.jpeg',
#   'data\\DAM\\KCI770VSOS03W.jpeg'],
#  'image-20210928-103731-9f1c8777': ['data\\DAM\\KCK278CRRS10W.jpeg',
#   'data\\DAM\\KCQ567NPTS77W.jpeg',
#   'data\\DAM\\KCQ718LABS38M.jpeg',
#   'data\\DAM\\KCK331CQCS03W.jpeg',
#   'data\\DAM\\KDI780VEAS03W.jpeg'],
#  'image-20210928-103742-55a72762': ['data\\DAM\\KCB608TJES34G.jpeg',
#   'data\\DAM\\KCK276NKRS900.jpeg',
#   'data\\DAM\\KCK351POBS56B.jpeg',
#   'data\\DAM\\KCK304CVES03W.jpeg',
#   'data\\DAM\\KCK382POBS56B.jpeg'],
#  'image-20210928-103754-89c16e1e': ['data\\DAM\\KCK276NKRS900.jpeg',
#   'data\\DAM\\KCK351POBS56B.jpeg',
#   'data\\DAM\\KCK306PUCS19W.jpeg',
#   'data\\DAM\\KCK233TOKS56B.jpeg',
#   'data\\DAM\\KCK382POBS56B.jpeg'],
#  'image-20210928-103807-7573be37': ['data\\DAM\\KCK276NKRS900.jpeg',
#   'data\\DAM\\KDB585DLPS26U.jpeg',
#   'data\\DAM\\KCK306PUCS19W.jpeg',
#   'data\\DAM\\KCK351POBS56B.jpeg',
#   'data\\DAM\\KCK354MLMS49K.jpeg'],
#  'image-20210928-103810-3cb15816': ['data\\DAM\\KCK276NKRS900.jpeg',
#   'data\\DAM\\KCK304CVES03W.jpeg',
#   'data\\DAM\\KCK231TLCS900.jpeg',
#   'data\\DAM\\KCK351POBS56B.jpeg',
#   'data\\DAM\\KCK177CVAS12X.jpeg'],
#  'image-20210928-103825-be7929ac': ['data\\DAM\\KDI701CFRS11X.jpeg',
#   'data\\DAM\\KCI592VSOS900.jpeg',
#   'data\\DAM\\KDI592VSOS900.jpeg',
#   'data\\DAM\\KDI774VEAS900.jpeg',
#   'data\\DAM\\KCK276NKRS900.jpeg'],
#  'IMG_6875': ['data\\DAM\\30MNTGN8072K.jpeg',
#   'data\\DAM\\30MNTGNSZJ1I.jpeg',
#   'data\\DAM\\DSGTS1UXR10A0.jpeg',
#   'data\\DAM\\DSGTA1UXR10A0.jpeg',
#   'data\\DAM\\SOSTELAIR38071I.jpeg'],
#  'IMG_6877': ['data\\DAM\\DSGTS1UXR10A0.jpeg',
#   'data\\DAM\\30MNRIR10A1.jpeg',
#   'data\\DAM\\SOSTELAIR38071I.jpeg',
#   'data\\DAM\\DSGTA1UXR10A0.jpeg',
#   'data\\DAM\\CLUBM4UWR45A0.jpeg'],
#  'IMG_6878': ['data\\DAM\\SOSTELAIR38071I.jpeg',
#   'data\\DAM\\DSGTS1UXR10A0.jpeg',
#   'data\\DAM\\DSGTA1UXR10A0.jpeg',
#   'data\\DAM\\30MNTGNSZJ1I.jpeg',
#   'data\\DAM\\30MNRIR10A1.jpeg'],
#  'IMG_6880': ['data\\DAM\\BOBYR1UXR42FR.jpeg',
#   'data\\DAM\\DSGTS1UXR10A0.jpeg',
#   'data\\DAM\\BOBYB1UXR40C0.jpeg',
#   'data\\DAM\\30MNRIR10A1.jpeg',
#   'data\\DAM\\DSGTR1UXR10A0.jpeg'],
#  'IMG_6881': ['data\\DAM\\DSGTS1UXR10A0.jpeg',
#   'data\\DAM\\30MNRIR10A1.jpeg',
#   'data\\DAM\\30MTSUR14A0.jpeg',
#   'data\\DAM\\SOSTELAIR38071I.jpeg',
#   'data\\DAM\\DIORCLAN2J5G1I.jpeg'],
#  'IMG_6883': ['data\\DAM\\DSGTS1UXR10A0.jpeg',
#   'data\\DAM\\30MTSUR14A0.jpeg',
#   'data\\DAM\\30MTS4UXGF0GP.jpeg',
#   'data\\DAM\\30MNTGN8072K.jpeg',
#   'data\\DAM\\JADIORKY2A9.jpeg'],
#  'IMG_6884': ['data\\DAM\\CDBM150050000.jpeg',
#   'data\\DAM\\CDBM150070000.jpeg',
#   'data\\DAM\\CDBM150060000.jpeg',
#   'data\\DAM\\DSGTS1UXR10A0.jpeg',
#   'data\\DAM\\30MTSUR14A0.jpeg'],
#  'IMG_6885': ['data\\DAM\\DSGTS1UXR10A0.jpeg',
#   'data\\DAM\\30MNRIR10A1.jpeg',
#   'data\\DAM\\DSGTR1UXR10A0.jpeg',
#   'data\\DAM\\30MTSUR14A0.jpeg',
#   'data\\DAM\\DSGTA1UXR10A0.jpeg'],
#  'IMG_6886': ['data\\DAM\\DIRECTIONDM2A9.jpeg',
#   'data\\DAM\\DSGTR1UXR10A0.jpeg',
#   'data\\DAM\\DSGTS1UXR10A0.jpeg',
#   'data\\DAM\\DSGTR1UXR26A1.jpeg',
#   'data\\DAM\\DSGTA1UXR10A0.jpeg'],
#  'IMG_6888': ['data\\DAM\\30MTSUMR41A0.jpeg',
#   'data\\DAM\\DSGTS1UXR10A0.jpeg',
#   'data\\DAM\\BOBYB1UXR40C0.jpeg',
#   'data\\DAM\\30MNTGN11EDO7.jpeg',
#   'data\\DAM\\30MTS4UXGF0GP.jpeg'],
#  'IMG_6889': ['data\\DAM\\30MNTGNSZJ1I.jpeg',
#   'data\\DAM\\30MNTGN8072K.jpeg',
#   'data\\DAM\\SOSTELAIR38071I.jpeg',
#   'data\\DAM\\STELLAIRE1LKSA9.jpeg',
#   'data\\DAM\\EVDRR1UQRD0F1.jpeg'],
#  'IMG_6891': ['data\\DAM\\M3550HLEZJM900.jpeg',
#   'data\\DAM\\S204SOLMJXM13L.jpeg',
#   'data\\DAM\\M0422PNAGM900.jpeg',
#   'data\\DAM\\S204SPLERXM42R.jpeg',
#   'data\\DAM\\S5619SLLOM989.jpeg'],
#  'IMG_6892': ['data\\DAM\\M9203UAHKXM50P.jpeg',
#   'data\\DAM\\M9204ULERXM423.jpeg',
#   'data\\DAM\\M500SPLERXM423.jpeg',
#   'data\\DAM\\M8641ULJGM889.jpeg',
#   'data\\DAM\\M0500JAWAXM41G.jpeg'],
#  'IMG_6893': ['data\\DAM\\M8641UPZGM889.jpeg',
#   'data\\DAM\\S0204ORERM885.jpeg',
#   'data\\DAM\\M8641ULJGM889.jpeg',
#   'data\\DAM\\S204SOLMJXM13L.jpeg',
#   'data\\DAM\\M0505OAWAXM85B.jpeg'],
#  'IMG_6894': ['data\\DAM\\M9204ULERXM423.jpeg',
#   'data\\DAM\\M9203UYECM90B.jpeg',
#   'data\\DAM\\M9203UTFQM928.jpeg',
#   'data\\DAM\\M9203UMOSM828.jpeg',
#   'data\\DAM\\M9204USJCM928.jpeg'],
#  'IMG_6896': ['data\\DAM\\124E11DM315X1848.jpeg',
#   'data\\DAM\\E1285MTGLQD17S.jpeg',
#   'data\\DAM\\CDBM150050000.jpeg',
#   'data\\DAM\\041B24A1212X9000.jpeg',
#   'data\\DAM\\M447SVAHLXM900.jpeg'],
#  'IMG_6898': ['data\\DAM\\M0447CANGM22L.jpeg',
#   'data\\DAM\\M0447CAATXM66F.jpeg',
#   'data\\DAM\\M447SCAATXM66F.jpeg',
#   'data\\DAM\\M0446CSJGM45E.jpeg',
#   'data\\DAM\\M447SCAHLXM50R.jpeg'],
#  'IMG_6899': ['data\\DAM\\M1286ZRGOM928.jpeg',
#   'data\\DAM\\M1265ZTDTM16E.jpeg',
#   'data\\DAM\\M1296ZTDTM932.jpeg',
#   'data\\DAM\\M1296ZJTKM932.jpeg',
#   'data\\DAM\\M1296ZRWDM918.jpeg'],
#  'IMG_6901': ['data\\DAM\\M0565ORHMM842.jpeg',
#   'data\\DAM\\M0565ORHMM918.jpeg',
#   'data\\DAM\\M1286ZRHMM918.jpeg',
#   'data\\DAM\\S5555CRHMM918.jpeg',
#   'data\\DAM\\M1286ZJAIM884.jpeg'],
#  'IMG_6902': ['data\\DAM\\M0447CWVGM52R.jpeg',
#   'data\\DAM\\M0447CANGM22L.jpeg',
#   'data\\DAM\\S2110UMOSM900.jpeg',
#   'data\\DAM\\M0538OCALM35R.jpeg',
#   'data\\DAM\\M5802CVQRM47R.jpeg'],
#  'IMG_6906': ['data\\DAM\\M505SOAHGM900.jpeg',
#   'data\\DAM\\M0565OJRLM941.jpeg',
#   'data\\DAM\\M0566JAZEXM900.jpeg',
#   'data\\DAM\\M565SOAAUXM830.jpeg',
#   'data\\DAM\\M565SOCYMXM85B.jpeg'],
#  'IMG_6908': ['data\\DAM\\M0538OCEAM39U.jpeg',
#   'data\\DAM\\M0505ILOIM030.jpeg',
#   'data\\DAM\\S0204OBBBM941.jpeg',
#   'data\\DAM\\M0531OWCBM26Y.jpeg',
#   'data\\DAM\\S0178OADUM11G.jpeg'],
#  'IMG_6909': ['data\\DAM\\S0204OAHGXM830.jpeg',
#   'data\\DAM\\M9242BWDEM090.jpeg',
#   'data\\DAM\\M565SOAAUXM830.jpeg',
#   'data\\DAM\\S0328OSKNM87K.jpeg',
#   'data\\DAM\\M0565JAHGXM830.jpeg'],
#  'IMG_6912': ['data\\DAM\\CD114561M0010000.jpeg',
#   'data\\DAM\\CD112114M0010000.jpeg',
#   'data\\DAM\\CD040110M0040000.jpeg',
#   'data\\DAM\\R1151ADRCYD908.jpeg',
#   'data\\DAM\\CD152110M0040000.jpeg'],
#  'IMG_6913': ['data\\DAM\\S2152OBAEM41G.jpeg',
#   'data\\DAM\\CDBM150050000.jpeg',
#   'data\\DAM\\CDBM150070000.jpeg',
#   'data\\DAM\\S0328CNOSM87B.jpeg',
#   'data\\DAM\\CDBM150060000.jpeg'],
#  'IMG_6914': ['data\\DAM\\R1151ADRCYD908.jpeg',
#   'data\\DAM\\CDBM150050000.jpeg',
#   'data\\DAM\\M505SJLDPXM06K.jpeg',
#   'data\\DAM\\CD114561M0010000.jpeg',
#   'data\\DAM\\M505SOLAAXM839.jpeg'],
#  'IMG_6918': ['data\\DAM\\11ABC106H600C850.jpeg',
#   'data\\DAM\\122J02X3376X0891.jpeg',
#   'data\\DAM\\11ABC106G600C640.jpeg',
#   'data\\DAM\\11MIF070I601C080.jpeg',
#   'data\\DAM\\25JAH106I606C528.jpeg'],
#  'IMG_6919': ['data\\DAM\\M0505INEAM030.jpeg',
#   'data\\DAM\\M0538BCALM34G.jpeg',
#   'data\\DAM\\M0505ILOIM030.jpeg',
#   'data\\DAM\\M0565ONGEM41G.jpeg',
#   'data\\DAM\\M0531PWRTM116.jpeg'],
#  'IMG_6921': ['data\\DAM\\M0565OJRLM941.jpeg',
#   'data\\DAM\\M505SOAHGM900.jpeg',
#   'data\\DAM\\M566SJAHGXM830.jpeg',
#   'data\\DAM\\M0565JAHGXM830.jpeg',
#   'data\\DAM\\M0538BCALM900.jpeg'],
#  'IMG_6924': ['data\\DAM\\KCB737SRXS900.jpeg',
#   'data\\DAM\\KCP261LSRS12U.jpeg',
#   'data\\DAM\\KCK276NKRS900.jpeg',
#   'data\\DAM\\KCB535PCOS17X.jpeg',
#   'data\\DAM\\24PCO106I611C988.jpeg'],
#  'IMG_6930': ['data\\DAM\\KCK299CNFS900.jpeg',
#   'data\\DAM\\KCK276NKRS900.jpeg',
#   'data\\DAM\\KCK231TLCS900.jpeg',
#   'data\\DAM\\KCK260TPNS29W.jpeg',
#   'data\\DAM\\KCK311VEAS900.jpeg'],
#  'IMG_6934': ['data\\DAM\\KCK325VEAS19O.jpeg',
#   'data\\DAM\\KCQ535NGGS12U.jpeg',
#   'data\\DAM\\KCQ567NPTS77W.jpeg',
#   'data\\DAM\\KCQ718LABS38M.jpeg',
#   'data\\DAM\\KCB737SRXS900.jpeg'],
#  'IMG_6940': ['data\\DAM\\KCQ266VEAS33H.jpeg',
#   'data\\DAM\\CLUBV1UXR11A0.jpeg',
#   'data\\DAM\\KCP261LSRS12U.jpeg',
#   'data\\DAM\\KCQ390VEAS54H.jpeg',
#   'data\\DAM\\E1285MTGLQD17S.jpeg'],
#  'IMG_6944': ['data\\DAM\\KCQ266VEAS33H.jpeg',
#   'data\\DAM\\KCQ439VEAS900.jpeg',
#   'data\\DAM\\KCQ266VEAS900.jpeg',
#   'data\\DAM\\KCQ536CSTS04X.jpeg',
#   'data\\DAM\\CLUBV1UXR11A0.jpeg'],
#  'IMG_6947': ['data\\DAM\\KCB668DGES10W.jpeg',
#   'data\\DAM\\KCK382POBS56B.jpeg',
#   'data\\DAM\\KDB585DLPS26U.jpeg',
#   'data\\DAM\\KDB578TJES36W.jpeg',
#   'data\\DAM\\KCQ166ERCS56B.jpeg'],
#  'IMG_6948': ['data\\DAM\\KDP916LNYS27G.jpeg',
#   'data\\DAM\\KDB704LNYS26U.jpeg',
#   'data\\DAM\\KDB805VNIS900.jpeg',
#   'data\\DAM\\KCP417SSYS900.jpeg',
#   'data\\DAM\\KCP845ACAS900.jpeg'],
#  'IMG_6949': ['data\\DAM\\KCP462PTRS900.jpeg',
#   'data\\DAM\\KDP510RPRS12U.jpeg',
#   'data\\DAM\\KDP882EMRS900.jpeg',
#   'data\\DAM\\KDP867CHSS900.jpeg',
#   'data\\DAM\\KCP268SPRS900.jpeg'],
#  'IMG_6950': ['data\\DAM\\KDI611SCNS52X.jpeg',
#   'data\\DAM\\KCI685SNYS42W.jpeg',
#   'data\\DAM\\KDI701CFRS11X.jpeg',
#   'data\\DAM\\KCI770VSOS03W.jpeg',
#   'data\\DAM\\KCI781VEAS17X.jpeg'],
#  'IMG_6951': ['data\\DAM\\KDC201VNRS03W.jpeg',
#   'data\\DAM\\KCC201VNRS900.jpeg',
#   'data\\DAM\\KCC200VNRS08U.jpeg',
#   'data\\DAM\\KCP462PTRS900.jpeg',
#   'data\\DAM\\KDC201TFLS900.jpeg'],
#  'IMG_6952': ['data\\DAM\\KDB805VNIS900.jpeg',
#   'data\\DAM\\KDB717ACAS44W.jpeg',
#   'data\\DAM\\KDB805VNIS03W.jpeg',
#   'data\\DAM\\KCB384VNRS03W.jpeg',
#   'data\\DAM\\KDB759ACAS11H.jpeg'],
#  'IMG_6953': ['data\\DAM\\KCI781VEAS17X.jpeg',
#   'data\\DAM\\KDI774VEAS900.jpeg',
#   'data\\DAM\\KCI592VSOS900.jpeg',
#   'data\\DAM\\KDI592VSOS900.jpeg',
#   'data\\DAM\\KDI701CFRS11X.jpeg'],
#  'IMG_6954': ['data\\DAM\\KDI613VEAS900.jpeg',
#   'data\\DAM\\KDI717VEAS900.jpeg',
#   'data\\DAM\\KCI717VEAS900.jpeg',
#   'data\\DAM\\KDI774VEAS900.jpeg',
#   'data\\DAM\\KDI609VSOS900.jpeg'],
#  'IMG_6955': ['data\\DAM\\KDI717VEAS900.jpeg',
#   'data\\DAM\\KCI717VEAS900.jpeg',
#   'data\\DAM\\KDI613VEAS900.jpeg',
#   'data\\DAM\\KCI592VSOS900.jpeg',
#   'data\\DAM\\KDI592VSOS900.jpeg'],
#  'IMG_6956': ['data\\DAM\\KCI491CFMS900.jpeg',
#   'data\\DAM\\KCI663CFFS900.jpeg',
#   'data\\DAM\\KDI774VEAS900.jpeg',
#   'data\\DAM\\KCI762NSRS900.jpeg',
#   'data\\DAM\\KCI589VEAS900.jpeg'],
#  'IMG_6957': ['data\\DAM\\KCK304CVES03W.jpeg',
#   'data\\DAM\\KCK382POBS56B.jpeg',
#   'data\\DAM\\KCK177CVAS12X.jpeg',
#   'data\\DAM\\KCK351POBS56B.jpeg',
#   'data\\DAM\\KCK331CQCS03W.jpeg'],
#  'IMG_6958': ['data\\DAM\\KCK304CVES03W.jpeg',
#   'data\\DAM\\KCK331CQCS03W.jpeg',
#   'data\\DAM\\KCK177CVAS12X.jpeg',
#   'data\\DAM\\KCK351POBS56B.jpeg',
#   'data\\DAM\\KCK306PUCS19W.jpeg'],
#  'IMG_6959': ['data\\DAM\\KCK351POBS56B.jpeg',
#   'data\\DAM\\KCK382POBS56B.jpeg',
#   'data\\DAM\\KCI661RCAS10W.jpeg',
#   'data\\DAM\\KCK276NKRS900.jpeg',
#   'data\\DAM\\KCK304CVES03W.jpeg'],
#  'IMG_6961': ['data\\DAM\\KCK318CMPS10W.jpeg',
#   'data\\DAM\\KCQ567NPTS77W.jpeg',
#   'data\\DAM\\KCK331CQCS03W.jpeg',
#   'data\\DAM\\KCK304CVES03W.jpeg',
#   'data\\DAM\\KCQ567NNPS66W.jpeg'],
#  'MicrosoftTeams-image_42': ['data\\DAM\\DSGTS1UXR10A0.jpeg',
#   'data\\DAM\\30MTSUR14A0.jpeg',
#   'data\\DAM\\CLUBM4UWR45A0.jpeg',
#   'data\\DAM\\30MNTGN8072K.jpeg',
#   'data\\DAM\\30MNTGN11EDO7.jpeg'],
#  'MicrosoftTeams-image_44': ['data\\DAM\\DSGTS1UXR10A0.jpeg',
#   'data\\DAM\\DSGTR1UXR10A0.jpeg',
#   'data\\DAM\\30MNRIR10A1.jpeg',
#   'data\\DAM\\DSGTA1UXR10A0.jpeg',
#   'data\\DAM\\SOSTELAIR38071I.jpeg'],
#  'MicrosoftTeams-image_45': ['data\\DAM\\DSGTS1UXR10A0.jpeg',
#   'data\\DAM\\SOSTELAIR38071I.jpeg',
#   'data\\DAM\\30MNTGN11EDO7.jpeg',
#   'data\\DAM\\NEWVOLUTERHLA9.jpeg',
#   'data\\DAM\\DSGTA1UXR10A0.jpeg'],
#  'MicrosoftTeams-image_46': ['data\\DAM\\DSGTS1UXR10A0.jpeg',
#   'data\\DAM\\30MNRIR10A1.jpeg',
#   'data\\DAM\\BOBYB1UXR40C0.jpeg',
#   'data\\DAM\\30MTSUR14A0.jpeg',
#   'data\\DAM\\BOBYR1UXR10A0.jpeg'],
#  'MicrosoftTeams-image_48': ['data\\DAM\\DSGTS1UXR10A0.jpeg',
#   'data\\DAM\\SOSTELAIR38071I.jpeg',
#   'data\\DAM\\30MNRIR10A1.jpeg',
#   'data\\DAM\\30MNTGN11EDO7.jpeg',
#   'data\\DAM\\SOSTELAIR1807YB.jpeg'],
#  'MicrosoftTeams-image_50': ['data\\DAM\\DSGTS1UXR10A0.jpeg',
#   'data\\DAM\\30MNRIR10A1.jpeg',
#   'data\\DAM\\30MTSUR14A0.jpeg',
#   'data\\DAM\\BOBYR1UXR10A0.jpeg',
#   'data\\DAM\\SOSTELAIR38071I.jpeg'],
#  'MicrosoftTeams-image_53': ['data\\DAM\\S5652CCEHM900.jpeg',
#   'data\\DAM\\S5652CWGSM919.jpeg',
#   'data\\DAM\\S5652CBAAM41G.jpeg',
#   'data\\DAM\\S5659CCEHM90B.jpeg',
#   'data\\DAM\\S5614CWGSM919.jpeg'],
#  'MicrosoftTeams-image_54': ['data\\DAM\\S5652CCEHM900.jpeg',
#   'data\\DAM\\M9203UTFQM928.jpeg',
#   'data\\DAM\\B0049CNOHM911.jpeg',
#   'data\\DAM\\S5673CBAAM900.jpeg',
#   'data\\DAM\\M3550HLEZJM900.jpeg']}

# %%
accuracy = 0
nb_guess = 0
for answer_key in answers.keys():
    found = 0
    if answer_key in guesses.keys():
        nb_guess += 1
        for value_guess in guesses[answer_key]:
            for value_answ in answers[answer_key]:
                if value_answ in value_guess and not found:
                    accuracy += 1
                    found = 1

accuracy/nb_guess*100
# Out:
# 57.14285714285714
